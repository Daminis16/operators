# %%
10 + 10
# Out:
# 20

# %%
# values should be stored in variable we cannot access this directly

# %%
a=10

# %%
a
# Out:
# 10

# %%
first_num=10
sec_num=20

# %%
result = first_num + sec_num

# %%
result
# Out:
# 30

# %%
'''
1. Arithmetic operators: - + / * // $ **
2. Assignment: -= += -+
3. Logical: and or not
4. Comparisson/relational: = <= >= != ==
5. identity: is is not
6. bitwise: >> <<
7. memebership: in not in
'''
# Out:
# '\n1. Arithmetic operators: - + / * // $ **\n2. Assignment: -= += -+\n3. Logical: and or not\n4. Comparisson/relational: = <= >= != ==\n5. identity: is is not\n6. bitwise: >> <<\n7. memebership: in not in\n'

# %%
a+10
b=3

# %%
a/b #integer+decimal
# Out:
# 3.3333333333333335

# %%
a//b #only integer value
# Out:
# 3

# %%
a%b #gives remainder and first remender
# Out:
# 1

# %%
a**b #to the power (exponent)
# Out:
# 1000

# %%
a=10 #assign value (assignment)

# %%
a+=1 #increment

# %%
a+=3

# %%
a
# Out:
# 14

# %%
# and not or(logical)

# %%
a=True
b=False

# %%
a or b
# Out:
# True

# %%
a and b
# Out:
# False

# %%
not a
# Out:
# False

# %%
5 > 7 or 7 < 5
# Out:
# False

# %%
not 5 > 7 or 7 < 5
# Out:
# True

# %%
not (5 > 7 or 7 < 5) #use parenthesis
# Out:
# True

# %%
a==b #(comparision) equal to
# Out:
# False

# %%
a = 20
b = '20'

# %%
a is b #(identity) ; checks whole value
# Out:
# False

# %%
a = "python"

# %%
'n' in a #membership : check any word in that
# Out:
# True

# %%
'n' not in a
# Out:
# False

# %% [raw]
# bitwise - >> <<

# %%
a = 12

# %%
a >> 2
# Out:
# 3

# %%
a << 2
# Out:
# 48
